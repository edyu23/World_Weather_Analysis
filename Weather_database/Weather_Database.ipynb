# %%
# Import the dependencies.
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low= -180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Orient the city count to confirm sufficient count
len(cities)
# Out:
# 721

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(f"{len(city_data)} city records were retrived")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | issa
# Processing Record 2 of Set 1 | matara
# Processing Record 3 of Set 1 | vardo
# Processing Record 4 of Set 1 | kandrian
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | bilma
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | nanortalik
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | moussoro
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | merauke
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | ostrovnoy
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | saint-pierre
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 1 | coquimbo
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | buenavista
# Processing Record 29 of Set 1 | torgau
# Processing Record 30 of Set 1 | vila franca do campo
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | kropotkin
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | mahibadhoo
# Processing Record 47 of Set 1 | southbridge
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | pisco
# Processing Record 1 of Set 2 | berlin
# Processing Record 2 of Set 2 | escarcega
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | ancud
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | kaeo
# Processing Record 10 of Set 2 | karachi
# Processing Record 11 of Set 2 | vao
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | launceston
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | college
# Processing Record 16 of Set 2 | semirom
# Processing Record 17 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | san ignacio
# Processing Record 20 of Set 2 | kaiyuan
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | nuuk
# Processing Record 23 of Set 2 | gayny
# Processing Record 24 of Set 2 | mulege
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | bouafle
# Processing Record 28 of Set 2 | sao paulo
# Processing Record 29 of Set 2 | namie
# Processing Record 30 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | broken hill
# Processing Record 33 of Set 2 | antofagasta
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | labuhan
# Processing Record 37 of Set 2 | podor
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | hue
# Processing Record 40 of Set 2 | sorland
# Processing Record 41 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 2 | kraljevo
# Processing Record 43 of Set 2 | anjangaon
# Processing Record 44 of Set 2 | vostok
# Processing Record 45 of Set 2 | yartsevo
# Processing Record 46 of Set 2 | santo angelo
# Processing Record 47 of Set 2 | berlevag
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | mareeba
# Processing Record 50 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | cadiz
# Processing Record 2 of Set 3 | hammerfest
# Processing Record 3 of Set 3 | katsiveli
# City not found. Skipping...
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | aklavik
# Processing Record 7 of Set 3 | touros
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | forio
# Processing Record 10 of Set 3 | acarau
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | badarpur
# Processing Record 13 of Set 3 | waipawa
# Processing Record 14 of Set 3 | constitucion
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | bell ville
# Processing Record 17 of Set 3 | sao francisco
# Processing Record 18 of Set 3 | mosalsk
# Processing Record 19 of Set 3 | prescott
# Processing Record 20 of Set 3 | deltona
# Processing Record 21 of Set 3 | nome
# Processing Record 22 of Set 3 | puerto rico
# Processing Record 23 of Set 3 | slave lake
# Processing Record 24 of Set 3 | itarema
# Processing Record 25 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 3 | san cristobal
# Processing Record 27 of Set 3 | lilongwe
# Processing Record 28 of Set 3 | hambantota
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | saint-augustin
# Processing Record 31 of Set 3 | codrington
# Processing Record 32 of Set 3 | shimorskoye
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | dongsheng
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | saint george
# Processing Record 38 of Set 3 | sola
# Processing Record 39 of Set 3 | shimoda
# Processing Record 40 of Set 3 | aripuana
# Processing Record 41 of Set 3 | storsteinnes
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 3 | san pedro
# Processing Record 45 of Set 3 | rawson
# Processing Record 46 of Set 3 | champerico
# Processing Record 47 of Set 3 | nemuro
# Processing Record 48 of Set 3 | yarada
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | jiwani
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | alabaster
# Processing Record 6 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | haines junction
# Processing Record 10 of Set 4 | matagami
# Processing Record 11 of Set 4 | nichinan
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | mizdah
# Processing Record 14 of Set 4 | oswego
# Processing Record 15 of Set 4 | batagay-alyta
# Processing Record 16 of Set 4 | jugsalai
# Processing Record 17 of Set 4 | zhezkazgan
# Processing Record 18 of Set 4 | khrebtovaya
# Processing Record 19 of Set 4 | iqaluit
# Processing Record 20 of Set 4 | tuktoyaktuk
# Processing Record 21 of Set 4 | keffi
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | rio grande
# Processing Record 24 of Set 4 | wanning
# Processing Record 25 of Set 4 | hofn
# Processing Record 26 of Set 4 | fort nelson
# Processing Record 27 of Set 4 | nantucket
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | hobart
# Processing Record 30 of Set 4 | namatanai
# Processing Record 31 of Set 4 | huaral
# Processing Record 32 of Set 4 | salinopolis
# Processing Record 33 of Set 4 | okhotsk
# Processing Record 34 of Set 4 | kapaa
# Processing Record 35 of Set 4 | bengkulu
# Processing Record 36 of Set 4 | yelizovo
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | cockburn town
# Processing Record 39 of Set 4 | santa ines
# Processing Record 40 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 4 | ahipara
# Processing Record 43 of Set 4 | puerto escondido
# Processing Record 44 of Set 4 | sistranda
# Processing Record 45 of Set 4 | wakkanai
# Processing Record 46 of Set 4 | poya
# Processing Record 47 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | motygino
# Processing Record 50 of Set 4 | hanko
# Processing Record 1 of Set 5 | trincomalee
# Processing Record 2 of Set 5 | noumea
# Processing Record 3 of Set 5 | ostersund
# Processing Record 4 of Set 5 | kalmunai
# Processing Record 5 of Set 5 | mahajanga
# Processing Record 6 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 7 of Set 5 | alofi
# Processing Record 8 of Set 5 | reconquista
# Processing Record 9 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 10 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 11 of Set 5 | birjand
# Processing Record 12 of Set 5 | leh
# Processing Record 13 of Set 5 | yar-sale
# Processing Record 14 of Set 5 | lisakovsk
# Processing Record 15 of Set 5 | lugovoy
# Processing Record 16 of Set 5 | svetlogorsk
# Processing Record 17 of Set 5 | karangasem
# Processing Record 18 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 19 of Set 5 | mitsamiouli
# Processing Record 20 of Set 5 | bac lieu
# Processing Record 21 of Set 5 | kulachi
# Processing Record 22 of Set 5 | hays
# Processing Record 23 of Set 5 | necochea
# Processing Record 24 of Set 5 | lebu
# Processing Record 25 of Set 5 | hilo
# Processing Record 26 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 27 of Set 5 | lasa
# Processing Record 28 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 5 | kerema
# Processing Record 30 of Set 5 | balaka
# Processing Record 31 of Set 5 | palana
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | turochak
# Processing Record 34 of Set 5 | biak
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | harper
# Processing Record 37 of Set 5 | benjamin aceval
# Processing Record 38 of Set 5 | vulcan
# Processing Record 39 of Set 5 | mount gambier
# Processing Record 40 of Set 5 | nabire
# Processing Record 41 of Set 5 | hirara
# Processing Record 42 of Set 5 | mana
# Processing Record 43 of Set 5 | la ronge
# Processing Record 44 of Set 5 | cayenne
# Processing Record 45 of Set 5 | half moon bay
# Processing Record 46 of Set 5 | nikolskoye
# Processing Record 47 of Set 5 | yerbogachen
# Processing Record 48 of Set 5 | carmen
# Processing Record 49 of Set 5 | gunjur
# Processing Record 50 of Set 5 | idrinskoye
# Processing Record 1 of Set 6 | shush
# Processing Record 2 of Set 6 | maloyaz
# City not found. Skipping...
# Processing Record 3 of Set 6 | sao filipe
# Processing Record 4 of Set 6 | tulagi
# Processing Record 5 of Set 6 | cabedelo
# Processing Record 6 of Set 6 | yeppoon
# Processing Record 7 of Set 6 | lotoshino
# Processing Record 8 of Set 6 | marawi
# Processing Record 9 of Set 6 | lermontovka
# Processing Record 10 of Set 6 | raudeberg
# Processing Record 11 of Set 6 | ferme-neuve
# Processing Record 12 of Set 6 | maitum
# Processing Record 13 of Set 6 | namibe
# Processing Record 14 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 6 | mahebourg
# Processing Record 16 of Set 6 | castro
# Processing Record 17 of Set 6 | fairbanks
# Processing Record 18 of Set 6 | trinidad
# Processing Record 19 of Set 6 | iisalmi
# Processing Record 20 of Set 6 | tazmalt
# Processing Record 21 of Set 6 | bubaque
# Processing Record 22 of Set 6 | husavik
# Processing Record 23 of Set 6 | kijang
# Processing Record 24 of Set 6 | isangel
# Processing Record 25 of Set 6 | porto novo
# Processing Record 26 of Set 6 | guadalupe victoria
# Processing Record 27 of Set 6 | olafsvik
# Processing Record 28 of Set 6 | kailua
# Processing Record 29 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 30 of Set 6 | massaguet
# Processing Record 31 of Set 6 | naryan-mar
# Processing Record 32 of Set 6 | narsaq
# Processing Record 33 of Set 6 | bara
# Processing Record 34 of Set 6 | mehriz
# Processing Record 35 of Set 6 | tateyama
# Processing Record 36 of Set 6 | provideniya
# Processing Record 37 of Set 6 | victoria
# Processing Record 38 of Set 6 | kodiak
# Processing Record 39 of Set 6 | tochio
# Processing Record 40 of Set 6 | ilorin
# Processing Record 41 of Set 6 | deputatskiy
# Processing Record 42 of Set 6 | aldan
# Processing Record 43 of Set 6 | nishihara
# Processing Record 44 of Set 6 | sheltozero
# Processing Record 45 of Set 6 | port hardy
# Processing Record 46 of Set 6 | lata
# Processing Record 47 of Set 6 | batemans bay
# Processing Record 48 of Set 6 | mount vernon
# Processing Record 49 of Set 6 | ust-tsilma
# Processing Record 50 of Set 6 | oum hadjer
# Processing Record 1 of Set 7 | ojinaga
# Processing Record 2 of Set 7 | klaksvik
# Processing Record 3 of Set 7 | jimo
# Processing Record 4 of Set 7 | langsa
# Processing Record 5 of Set 7 | talakan
# Processing Record 6 of Set 7 | waingapu
# Processing Record 7 of Set 7 | chepareria
# Processing Record 8 of Set 7 | egvekinot
# Processing Record 9 of Set 7 | auki
# Processing Record 10 of Set 7 | sur
# Processing Record 11 of Set 7 | hosakote
# Processing Record 12 of Set 7 | papa
# Processing Record 13 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 7 | stornoway
# Processing Record 15 of Set 7 | tiznit
# Processing Record 16 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 7 | oktyabrskiy
# Processing Record 18 of Set 7 | luanda
# Processing Record 19 of Set 7 | anadyr
# Processing Record 20 of Set 7 | karpathos
# Processing Record 21 of Set 7 | krasnyy bogatyr
# Processing Record 22 of Set 7 | roald
# Processing Record 23 of Set 7 | huilong
# Processing Record 24 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 7 | guerrero negro
# Processing Record 27 of Set 7 | ixtapa
# Processing Record 28 of Set 7 | hervey bay
# Processing Record 29 of Set 7 | gao
# Processing Record 30 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 33 of Set 7 | chapais
# Processing Record 34 of Set 7 | turukhansk
# Processing Record 35 of Set 7 | kingisepp
# Processing Record 36 of Set 7 | san luis
# Processing Record 37 of Set 7 | kota
# Processing Record 38 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | ambon
# Processing Record 40 of Set 7 | ullal
# Processing Record 41 of Set 7 | lively
# Processing Record 42 of Set 7 | livingston
# Processing Record 43 of Set 7 | nicholasville
# Processing Record 44 of Set 7 | tiksi
# Processing Record 45 of Set 7 | neuquen
# Processing Record 46 of Set 7 | talnakh
# Processing Record 47 of Set 7 | tocopilla
# Processing Record 48 of Set 7 | basti
# Processing Record 49 of Set 7 | mehamn
# Processing Record 50 of Set 7 | ascension
# Processing Record 1 of Set 8 | dolores
# Processing Record 2 of Set 8 | ballina
# Processing Record 3 of Set 8 | pechenga
# Processing Record 4 of Set 8 | kurilsk
# Processing Record 5 of Set 8 | puerto narino
# Processing Record 6 of Set 8 | carutapera
# Processing Record 7 of Set 8 | arrifes
# Processing Record 8 of Set 8 | umm kaddadah
# Processing Record 9 of Set 8 | birao
# Processing Record 10 of Set 8 | kulhudhuffushi
# Processing Record 11 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 8 | baykit
# Processing Record 13 of Set 8 | najran
# Processing Record 14 of Set 8 | yuancheng
# Processing Record 15 of Set 8 | havre-saint-pierre
# Processing Record 16 of Set 8 | san quintin
# Processing Record 17 of Set 8 | kudahuvadhoo
# Processing Record 18 of Set 8 | moba
# Processing Record 19 of Set 8 | parabel
# Processing Record 20 of Set 8 | tahoua
# Processing Record 21 of Set 8 | jijiga
# Processing Record 22 of Set 8 | slonim
# Processing Record 23 of Set 8 | marfino
# Processing Record 24 of Set 8 | ternate
# Processing Record 25 of Set 8 | bambous virieux
# Processing Record 26 of Set 8 | barcelos
# Processing Record 27 of Set 8 | palaikastron
# Processing Record 28 of Set 8 | avera
# Processing Record 29 of Set 8 | mongoumba
# Processing Record 30 of Set 8 | sebring
# Processing Record 31 of Set 8 | comodoro rivadavia
# Processing Record 32 of Set 8 | nizhneangarsk
# Processing Record 33 of Set 8 | bathsheba
# Processing Record 34 of Set 8 | kaseda
# Processing Record 35 of Set 8 | ornskoldsvik
# Processing Record 36 of Set 8 | shimanovsk
# Processing Record 37 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 38 of Set 8 | condado
# Processing Record 39 of Set 8 | puerto baquerizo moreno
# Processing Record 40 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 8 | talas
# Processing Record 42 of Set 8 | ha tinh
# Processing Record 43 of Set 8 | ilulissat
# Processing Record 44 of Set 8 | tevriz
# Processing Record 45 of Set 8 | imbituba
# Processing Record 46 of Set 8 | sakakah
# Processing Record 47 of Set 8 | tura
# Processing Record 48 of Set 8 | roberto payan
# City not found. Skipping...
# Processing Record 49 of Set 8 | amapa
# Processing Record 50 of Set 8 | taltal
# Processing Record 1 of Set 9 | xichang
# Processing Record 2 of Set 9 | beidao
# Processing Record 3 of Set 9 | big rapids
# Processing Record 4 of Set 9 | puerto del rosario
# Processing Record 5 of Set 9 | jurado
# Processing Record 6 of Set 9 | apastovo
# Processing Record 7 of Set 9 | padang
# Processing Record 8 of Set 9 | maxixe
# Processing Record 9 of Set 9 | taitung
# Processing Record 10 of Set 9 | gustavo diaz ordaz
# Processing Record 11 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 12 of Set 9 | effingham
# Processing Record 13 of Set 9 | filingue
# Processing Record 14 of Set 9 | dajal
# Processing Record 15 of Set 9 | san andres
# Processing Record 16 of Set 9 | luderitz
# Processing Record 17 of Set 9 | paita
# Processing Record 18 of Set 9 | peleduy
# Processing Record 19 of Set 9 | suntar
# Processing Record 20 of Set 9 | minuwangoda
# Processing Record 21 of Set 9 | yerofey pavlovich
# Processing Record 22 of Set 9 | alice town
# Processing Record 23 of Set 9 | inuvik
# Processing Record 24 of Set 9 | flin flon
# Processing Record 25 of Set 9 | young
# Processing Record 26 of Set 9 | guangyuan
# Processing Record 27 of Set 9 | macamic
# Processing Record 28 of Set 9 | ankpa
# Processing Record 29 of Set 9 | port hedland
# Processing Record 30 of Set 9 | limon
# Processing Record 31 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 9 | alberton
# Processing Record 33 of Set 9 | kauhajoki
# Processing Record 34 of Set 9 | petropavl
# Processing Record 35 of Set 9 | nador
# Processing Record 36 of Set 9 | mayor pablo lagerenza
# Processing Record 37 of Set 9 | kurumkan
# Processing Record 38 of Set 9 | xining
# Processing Record 39 of Set 9 | beloha
# Processing Record 40 of Set 9 | adrar
# Processing Record 41 of Set 9 | cherskiy
# Processing Record 42 of Set 9 | kungurtug
# Processing Record 43 of Set 9 | moyale
# Processing Record 44 of Set 9 | jagalur
# Processing Record 45 of Set 9 | consuegra
# Processing Record 46 of Set 9 | viesite
# Processing Record 47 of Set 9 | udachnyy
# Processing Record 48 of Set 9 | ukiah
# Processing Record 49 of Set 9 | derzhavinsk
# Processing Record 50 of Set 9 | saveh
# Processing Record 1 of Set 10 | bolshaya rechka
# Processing Record 2 of Set 10 | biloela
# Processing Record 3 of Set 10 | san jose
# Processing Record 4 of Set 10 | opuwo
# Processing Record 5 of Set 10 | lorengau
# Processing Record 6 of Set 10 | ayan
# Processing Record 7 of Set 10 | bulgan
# Processing Record 8 of Set 10 | luba
# Processing Record 9 of Set 10 | dickson
# Processing Record 10 of Set 10 | gdansk
# Processing Record 11 of Set 10 | kununurra
# Processing Record 12 of Set 10 | yalchiki
# City not found. Skipping...
# Processing Record 13 of Set 10 | watsa
# Processing Record 14 of Set 10 | glenwood springs
# Processing Record 15 of Set 10 | kaitong
# Processing Record 16 of Set 10 | kavaratti
# Processing Record 17 of Set 10 | goderich
# Processing Record 18 of Set 10 | libertador general san martin
# Processing Record 19 of Set 10 | east wenatchee bench
# Processing Record 20 of Set 10 | orgun
# City not found. Skipping...
# Processing Record 21 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 10 | mackenzie
# Processing Record 23 of Set 10 | maceio
# Processing Record 24 of Set 10 | thinadhoo
# Processing Record 25 of Set 10 | bergneustadt
# Processing Record 26 of Set 10 | matay
# Processing Record 27 of Set 10 | willowmore
# Processing Record 28 of Set 10 | santa rosa
# Processing Record 29 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 30 of Set 10 | macklin
# Processing Record 31 of Set 10 | ketchikan
# Processing Record 32 of Set 10 | kuah
# Processing Record 33 of Set 10 | sanarate
# Processing Record 34 of Set 10 | bam
# Processing Record 35 of Set 10 | gambo
# Processing Record 36 of Set 10 | wanaka
# Processing Record 37 of Set 10 | mpika
# Processing Record 38 of Set 10 | rawlins
# Processing Record 39 of Set 10 | grindavik
# Processing Record 40 of Set 10 | tanete
# Processing Record 41 of Set 10 | christchurch
# Processing Record 42 of Set 10 | tyret pervaya
# Processing Record 43 of Set 10 | chimbote
# Processing Record 44 of Set 10 | norrtalje
# Processing Record 45 of Set 10 | figeac
# Processing Record 46 of Set 10 | springbok
# Processing Record 47 of Set 10 | mirnyy
# Processing Record 48 of Set 10 | poum
# Processing Record 49 of Set 10 | quatre cocos
# Processing Record 50 of Set 10 | ranong
# Processing Record 1 of Set 11 | havre
# Processing Record 2 of Set 11 | manjacaze
# Processing Record 3 of Set 11 | yulara
# Processing Record 4 of Set 11 | qasigiannguit
# Processing Record 5 of Set 11 | fortuna
# Processing Record 6 of Set 11 | nueve de julio
# Processing Record 7 of Set 11 | saldanha
# Processing Record 8 of Set 11 | vestmannaeyjar
# Processing Record 9 of Set 11 | bom jesus
# Processing Record 10 of Set 11 | gasa
# Processing Record 11 of Set 11 | pala
# Processing Record 12 of Set 11 | alice springs
# Processing Record 13 of Set 11 | kursk
# Processing Record 14 of Set 11 | alanya
# Processing Record 15 of Set 11 | columbus
# Processing Record 16 of Set 11 | alpoyeca
# Processing Record 17 of Set 11 | port lincoln
# Processing Record 18 of Set 11 | amahai
# Processing Record 19 of Set 11 | brumunddal
# Processing Record 20 of Set 11 | abnub
# Processing Record 21 of Set 11 | garowe
# Processing Record 22 of Set 11 | inhambane
# Processing Record 23 of Set 11 | palu
# Processing Record 24 of Set 11 | zelenoborskiy
# Processing Record 25 of Set 11 | ndele
# Processing Record 26 of Set 11 | katha
# City not found. Skipping...
# Processing Record 27 of Set 11 | houma
# Processing Record 28 of Set 11 | lazaro cardenas
# Processing Record 29 of Set 11 | kon tum
# Processing Record 30 of Set 11 | aksha
# Processing Record 31 of Set 11 | bandar-e lengeh
# Processing Record 32 of Set 11 | phuket
# Processing Record 33 of Set 11 | kautokeino
# Processing Record 34 of Set 11 | sidlaghatta
# Processing Record 35 of Set 11 | panjab
# Processing Record 36 of Set 11 | xuanzhou
# Processing Record 37 of Set 11 | great bend
# Processing Record 38 of Set 11 | elin pelin
# Processing Record 39 of Set 11 | kiunga
# Processing Record 40 of Set 11 | esil
# Processing Record 41 of Set 11 | taywarah
# Processing Record 42 of Set 11 | sohag
# Processing Record 43 of Set 11 | dindori
# Processing Record 44 of Set 11 | karratha
# Processing Record 45 of Set 11 | nouadhibou
# Processing Record 46 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 11 | erzurum
# Processing Record 49 of Set 11 | kaduqli
# Processing Record 50 of Set 11 | willmar
# Processing Record 1 of Set 12 | chilapa
# Processing Record 2 of Set 12 | boa vista
# Processing Record 3 of Set 12 | severo-yeniseyskiy
# Processing Record 4 of Set 12 | taoudenni
# Processing Record 5 of Set 12 | shitanjing
# Processing Record 6 of Set 12 | nizhniy odes
# Processing Record 7 of Set 12 | dalvik
# Processing Record 8 of Set 12 | izhma
# Processing Record 9 of Set 12 | de la paz
# Processing Record 10 of Set 12 | jiaojiang
# Processing Record 11 of Set 12 | abilene
# Processing Record 12 of Set 12 | morehead
# Processing Record 13 of Set 12 | kanniyakumari
# Processing Record 14 of Set 12 | roseburg
# Processing Record 15 of Set 12 | gamba
# Processing Record 16 of Set 12 | beni
# Processing Record 17 of Set 12 | bani
# Processing Record 18 of Set 12 | vanimo
# Processing Record 19 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 20 of Set 12 | abu samrah
# Processing Record 21 of Set 12 | mega
# Processing Record 22 of Set 12 | alenquer
# Processing Record 23 of Set 12 | kahului
# Processing Record 24 of Set 12 | jalu
# Processing Record 25 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 12 | waw
# Processing Record 27 of Set 12 | margate
# Processing Record 28 of Set 12 | kashin
# Processing Record 29 of Set 12 | belmonte
# Processing Record 30 of Set 12 | caravelas
# Processing Record 31 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 12 | nanfeng
# Processing Record 33 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 12 | luwuk
# Processing Record 35 of Set 12 | evensk
# Processing Record 36 of Set 12 | batsfjord
# Processing Record 37 of Set 12 | panaba
# Processing Record 38 of Set 12 | mountain home
# Processing Record 39 of Set 12 | kaihua
# Processing Record 40 of Set 12 | menongue
# Processing Record 41 of Set 12 | cravo norte
# Processing Record 42 of Set 12 | clyde
# Processing Record 43 of Set 12 | eschwege
# Processing Record 44 of Set 12 | outjo
# Processing Record 45 of Set 12 | san juan
# Processing Record 46 of Set 12 | sitka
# Processing Record 47 of Set 12 | primorsk
# Processing Record 48 of Set 12 | sept-iles
# Processing Record 49 of Set 12 | broome
# Processing Record 50 of Set 12 | shingu
# Processing Record 1 of Set 13 | lagoa
# Processing Record 2 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 3 of Set 13 | san patricio
# Processing Record 4 of Set 13 | mayumba
# Processing Record 5 of Set 13 | baarn
# Processing Record 6 of Set 13 | wewak
# Processing Record 7 of Set 13 | komsomolskiy
# Processing Record 8 of Set 13 | abalak
# Processing Record 9 of Set 13 | sao paulo de olivenca
# Processing Record 10 of Set 13 | asfi
# Processing Record 11 of Set 13 | joniskelis
# Processing Record 12 of Set 13 | texarkana
# Processing Record 13 of Set 13 | fare
# Processing Record 14 of Set 13 | palmer
# Processing Record 15 of Set 13 | agva
# City not found. Skipping...
# Processing Record 16 of Set 13 | scottsboro
# Processing Record 17 of Set 13 | kattivakkam
# Processing Record 18 of Set 13 | totness
# Processing Record 19 of Set 13 | brae
# Processing Record 20 of Set 13 | pineville
# Processing Record 21 of Set 13 | sao francisco de paula
# Processing Record 22 of Set 13 | alegrete
# Processing Record 23 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 24 of Set 13 | pedasi
# Processing Record 25 of Set 13 | antalaha
# Processing Record 26 of Set 13 | stokmarknes
# Processing Record 27 of Set 13 | podujevo
# Processing Record 28 of Set 13 | mangit
# Processing Record 29 of Set 13 | muzhi
# Processing Record 30 of Set 13 | chino valley
# Processing Record 31 of Set 13 | loiza
# Processing Record 32 of Set 13 | selfoss
# Processing Record 33 of Set 13 | bay roberts
# Processing Record 34 of Set 13 | khani
# Processing Record 35 of Set 13 | conde
# Processing Record 36 of Set 13 | ocampo
# Processing Record 37 of Set 13 | jaffna
# Processing Record 38 of Set 13 | iwaki
# Processing Record 39 of Set 13 | makat
# Processing Record 40 of Set 13 | dagda
# Processing Record 41 of Set 13 | te anau
# Processing Record 42 of Set 13 | matadi
# Processing Record 43 of Set 13 | juneau
# Processing Record 44 of Set 13 | flagstaff
# Processing Record 45 of Set 13 | manzhouli
# Processing Record 46 of Set 13 | liverpool
# Processing Record 47 of Set 13 | mugur-aksy
# Processing Record 48 of Set 13 | hualmay
# Processing Record 49 of Set 13 | hobyo
# Processing Record 50 of Set 13 | kitaibaraki
# Processing Record 1 of Set 14 | batagay
# Processing Record 2 of Set 14 | dudinka
# Processing Record 3 of Set 14 | abu kamal
# Processing Record 4 of Set 14 | buraydah
# Processing Record 5 of Set 14 | north bend
# Processing Record 6 of Set 14 | strzelce krajenskie
# Processing Record 7 of Set 14 | los llanos de aridane
# Processing Record 8 of Set 14 | owando
# Processing Record 9 of Set 14 | atar
# Processing Record 10 of Set 14 | isla mujeres
# Processing Record 11 of Set 14 | makueni
# Processing Record 12 of Set 14 | nefteyugansk
# Processing Record 13 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 14 | marystown
# Processing Record 15 of Set 14 | invermere
# Processing Record 16 of Set 14 | mahanoro
# Processing Record 17 of Set 14 | aden
# Processing Record 18 of Set 14 | kuala terengganu
# Processing Record 19 of Set 14 | deder
# Processing Record 20 of Set 14 | basoko
# Processing Record 21 of Set 14 | morgan city
# Processing Record 22 of Set 14 | balkanabat
# Processing Record 23 of Set 14 | shelburne
# Processing Record 24 of Set 14 | canton
# Processing Record 25 of Set 14 | nizhniy tsasuchey
# Processing Record 26 of Set 14 | ridgecrest
# Processing Record 27 of Set 14 | tyup
# Processing Record 28 of Set 14 | kumbhraj
# Processing Record 29 of Set 14 | mundo nuevo
# Processing Record 30 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 31 of Set 14 | neiafu
# Processing Record 32 of Set 14 | novopokrovka
# Processing Record 33 of Set 14 | paamiut
# Processing Record 34 of Set 14 | pundaguitan
# Processing Record 35 of Set 14 | kaka
# Processing Record 36 of Set 14 | tessalit
# Processing Record 37 of Set 14 | urengoy
# Processing Record 38 of Set 14 | victoria point
# Processing Record 39 of Set 14 | guicheng
# City not found. Skipping...
# Processing Record 40 of Set 14 | cap malheureux
# Processing Record 41 of Set 14 | bachaquero
# Processing Record 42 of Set 14 | khasan
# Processing Record 43 of Set 14 | estancia
# Processing Record 44 of Set 14 | betsiamites
# Processing Record 45 of Set 14 | markova
# Processing Record 46 of Set 14 | mpanda
# Processing Record 47 of Set 14 | natal
# Processing Record 48 of Set 14 | iralaya
# Processing Record 49 of Set 14 | tuatapere
# Processing Record 50 of Set 14 | straumen
# Processing Record 1 of Set 15 | fayaoue
# Processing Record 2 of Set 15 | catamarca
# Processing Record 3 of Set 15 | celestun
# Processing Record 4 of Set 15 | parambu
# Processing Record 5 of Set 15 | onega
# Processing Record 6 of Set 15 | lanzhou
# Processing Record 7 of Set 15 | san lorenzo
# Processing Record 8 of Set 15 | maragogi
# Processing Record 9 of Set 15 | ciudad valles
# Processing Record 10 of Set 15 | nha trang
# Processing Record 11 of Set 15 | lakes entrance
# Processing Record 12 of Set 15 | kommunisticheskiy
# Processing Record 13 of Set 15 | meru
# Processing Record 14 of Set 15 | nhulunbuy
# Processing Record 15 of Set 15 | ust-ishim
# Processing Record 16 of Set 15 | beringovskiy
# Processing Record 17 of Set 15 | wilmington
# Processing Record 18 of Set 15 | kagoro
# Processing Record 19 of Set 15 | omboue
# Processing Record 20 of Set 15 | qandala
# Processing Record 21 of Set 15 | portland
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 663 city records were retrived

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Issa  53.8705   44.8578     47.03        63          77
# 1           Matara   5.9485   80.5353     79.12        88          92
# 2            Vardo  70.3705   31.1107     37.38        75          75
# 3         Kandrian  -6.2167  149.5500     77.67        89          44
# 4          Rikitea -23.1203 -134.9692     73.47        80         100
# 5            Bilma  18.6853   12.9164     99.99        12          98
# 6          Mataura -46.1927  168.8643     41.41        94         100
# 7       Nanortalik  60.1432  -45.2371     38.70        75          79
# 8  Arraial Do Cabo -22.9661  -42.0278     69.76        73          40
# 9     Punta Arenas -53.1500  -70.9167     41.11        87         100
#
#    Wind Speed Country Current Description
# 0       16.28      RU       broken clouds
# 1        8.59      LK     overcast clouds
# 2       16.11      NO       broken clouds
# 3        6.35      PG          light rain
# 4       11.59      PF     overcast clouds
# 5       23.15      NE     overcast clouds
# 6       12.66      NZ          light rain
# 7        6.24      GL       broken clouds
# 8       21.85      BR    scattered clouds
# 9        6.91      CL     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the CIty_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
